# %%
import requests
import pandas as pd
import json
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=60min&apikey=E5CX4VOWGQH169RE'
r = requests.get(url)
data = r.json()

#jsonData = json.loads(data)
#type(jsonData)
#print(jsonData)

#print(data[2]["2. Symbol"])

#print(data)

#print(list(data.keys()))

#keys_to_use = ['Time Series (60min)']

#with open("data.json", "w") as outfile:
    #json.dump(data, outfile)

#print(data)
#pd.json_normalize(data)

def get_record_from_json(file_path, keys):
    with open (file_path) as artwork_file:
        content = json.load(artwork_file)

    record = []
    for field in keys:
        record.append(content[field])
        print(record)

    return (record)
    



test_record = get_record_from_json("data.json", keys_to_use)

print(test_record)

print(type(test_record))

print(len(test_record))

key, val = test_record.items()[0]

print(key, val)
# Out:
# [{'2022-12-07 20:00:00': {'1. open': '147.2300', '2. high': '147.2300', '3. low': '147.2100', '4. close': '147.2100', '5. volume': '1199'}, '2022-12-07 17:00:00': {'1. open': '147.2700', '2. high': '147.2700', '3. low': '147.1300', '4. close': '147.2700', '5. volume': '118114'}, '2022-12-07 16:00:00': {'1. open': '147.4750', '2. high': '147.6400', '3. low': '147.1100', '4. close': '147.2700', '5. volume': '611497'}, '2022-12-07 15:00:00': {'1. open': '147.4500', '2. high': '147.6700', '3. low': '147.2000', '4. close': '147.4750', '5. volume': '327167'}, '2022-12-07 14:00:00': {'1. open': '147.5410', '2. high': '148.1050', '3. low': '147.3576', '4. close': '147.4500', '5. volume': '429556'}, '2022-12-07 13:00:00': {'1. open': '147.3599', '2. high': '147.9496', '3. low': '147.2400', '4. close': '147.5513', '5. volume': '613768'}, '2022-12-07 12:00:00': {'1. open': '147.2500', '2. high': '147.3700', '3. low': '146.7317', '4. close': '147.3244', '5. volume': '354738'}, '2022-12-07 11:00:
# ...
